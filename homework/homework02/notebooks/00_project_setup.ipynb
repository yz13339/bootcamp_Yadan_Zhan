# %% [markdown]
# # Environment & Config Check
#
# Verify that the local environment, dummy configuration, and NumPy are working.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root))

from src.config import get_key, load_env

load_env()
print(f"API_KEY present: {bool(get_key('API_KEY'))}")
print(f"DATA_DIR: {get_key('DATA_DIR')}")
# Out:
# API_KEY present: True
# DATA_DIR: ./data

# %%
import numpy as np

values = np.array([1, 2, 3, 4])
print(f"Array: {values}")
print(f"Mean: {values.mean()}")
# Out:
# Array: [1 2 3 4]
# Mean: 2.5
