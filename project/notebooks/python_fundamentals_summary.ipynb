# %%
import numpy as np
import pandas as pd

# %%
market_data = {
    "date": ["2026-01-01", "2026-01-02", "2026-01-03"],
    "spy": [500, 495, 490],
    "vix": [15, 18, 22],
    "tlt": [90, 91, 92],
    "gld": [180, 182, 184]
}

df = pd.DataFrame(market_data)

# %%
df.info()
df.describe()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3 non-null      object
#  1   spy     3 non-null      int64
#  2   vix     3 non-null      int64
#  3   tlt     3 non-null      int64
#  4   gld     3 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 248.0+ bytes
# date    0
# spy     0
# vix     0
# tlt     0
# gld     0
# dtype: int64

# %% [markdown]
# ## Reusable Utility Function
#
# The `clean_column_names()` function standardizes DataFrame column names by
# removing extra spaces, converting text to lowercase, and replacing spaces with
# underscores. It will be reused in later stages when market data are downloaded
# from external sources.
